# %% [markdown]
# # Seminário PC III — Coverage
# **Gabriel Martins Nunes e Rafaela Garcia Bernardes**
# Tema 8: métricas e cobertura de código com `pytest` e `coverage.py`.
#
# > Antes de executar, faça upload da pasta do projeto (ou descompacte o ZIP) e ajuste o `%cd` da célula seguinte, se necessário.

# %%
# %cd /content/seminario_pc3_coverage
# !pip -q install -r requirements.txt

# %% [markdown]
# ## Suíte final
# O `pytest` informa se as regras verificadas pelos testes passaram.

# %%
# !pytest -v

# %% [markdown]
# ## Cenário inicial: teste verde, cobertura incompleta
# O teste abaixo só percorre o caminho do cliente VIP.

# %%
# !coverage erase
# !coverage run --branch -m pytest roteiro_live/teste_inicial.py -v
# !coverage report -m

# %% [markdown]
# ## Suíte ampliada: statement e branch coverage
# Agora a suíte contempla os caminhos de negócio, o limite e a exceção.

# %%
# !coverage erase
# !coverage run --branch -m pytest -v
# !coverage report -m
# !coverage html
from IPython.display import HTML, display
display(HTML(open('htmlcov/index.html', encoding='utf-8').read()))

# %% [markdown]
# ## Mensagem final
# Coverage responde **quanto** do código foi executado. Bons testes respondem se o comportamento certo foi realmente verificado.
